# %%
"""
config.py — Shared configuration for the car classifier pipeline.
All hyperparameters, paths, and constants live here.
"""

import os
import torch

DATA_DIR = os.environ.get("CAR_DATA_DIR", "data/Cars Dataset")
OUTPUT_DIR = "outputs"

# Data Split Ratios ---- MUST SUM TO 1.0
TRAIN_RATIO = 0.7
VAL_RATIO = 0.15
TEST_RATIO = 0.15

# Image settings -------
IMG_SIZE = 300
IMG_EXTS = (".jpg", ".jpeg", ".png")

# Training settings ---- Hyperparameters for training the model.
BATCH_SIZE = 32
N_EPOCHS = 25
LR = 1e-3
NUM_WORKERS = 4

# Hardware settings ---- Device configuration for training.
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Model ----- 
BACKBONE = "efficientnet_b3"
PRETRAINED = True  # Whether to use pretrained weights for the backbone

# Reproducibility ---- Random seeds for reproducibility.
RANDOM_SEED = 42    

# ImageNet normalization values for pretrained models
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

# Auto-scale settings based on available hardware
if DEVICE == "cpu":
    BATCH_SIZE = 8
    N_EPOCHS = 10
